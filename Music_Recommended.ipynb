# %%
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity

# Load dataset
df = pd.read_csv("music_recommendation_dataset.csv")

# Features used for recommendation
features = [
    "Energy",
    "Danceability",
    "Acousticness",
    "Valence"
]

# Convert features into numerical values
scaler = StandardScaler()
feature_matrix = scaler.fit_transform(df[features])

# Calculate similarity between songs
similarity_matrix = cosine_similarity(feature_matrix)


def recommend_songs(song_name, number_of_recommendations=5):

    # Find the selected song
    song_index = df[df["Song"].str.lower() == song_name.lower()].index

    if len(song_index) == 0:
        print("Song not found!")
        return

    song_index = song_index[0]

    # Get similarity scores
    similarity_scores = list(
        enumerate(similarity_matrix[song_index])
    )

    # Sort songs according to similarity
    similarity_scores = sorted(
        similarity_scores,
        key=lambda x: x[1],
        reverse=True
    )

    print("\nRecommended Songs:")
    print("------------------")

    count = 0

    for index, score in similarity_scores:

        # Don't recommend the same song
        if index == song_index:
            continue

        print(
            df.iloc[index]["Song"],
            "-",
            df.iloc[index]["Artist"],
            "| Similarity:",
            round(score, 2)
        )

        count += 1

        if count == number_of_recommendations:
            break


# Example
recommend_songs("Blinding Lights", 5)
# Out:
# Recommended Songs:
# ------------------
# Believer - Imagine Dragons | Similarity: 0.98
# Don't Start Now - Dua Lipa | Similarity: 0.87
# Rolling in the Deep - Adele | Similarity: 0.87
# Attention - Charlie Puth | Similarity: 0.87
# On My Way - Alan Walker | Similarity: 0.86

# %%
# %%writefile app.py

import streamlit as st
import pandas as pd
from sklearn.preprocessing import StandardScaler
from sklearn.metrics.pairwise import cosine_similarity

# Page configuration
st.set_page_config(
    page_title="Music Recommendation System",
    page_icon="🎵",
    layout="centered"
)

st.title("🎵 Personalized Music Recommendation System")

st.write(
    "Select a song and get personalized song recommendations "
    "based on music similarity."
)

# Load dataset
df = pd.read_csv("music_data.csv")

# Features
features = [
    "energy",
    "danceability",
    "acousticness",
    "valence"
]

# Scale features
scaler = StandardScaler()
feature_matrix = scaler.fit_transform(df[features])

# Calculate similarity
similarity_matrix = cosine_similarity(feature_matrix)

# Select song
song_list = df["song"].tolist()

selected_song = st.selectbox(
    "🎧 Select a song",
    song_list
)

number_of_recommendations = st.slider(
    "Number of recommendations",
    min_value=1,
    max_value=5,
    value=3
)

if st.button("🎵 Recommend Songs"):

    song_index = df[
        df["song"] == selected_song
    ].index[0]

    similarity_scores = list(
        enumerate(similarity_matrix[song_index])
    )

    similarity_scores = sorted(
        similarity_scores,
        key=lambda x: x[1],
        reverse=True
    )

    st.subheader("🎶 Recommended Songs")

    count = 0

    for index, score in similarity_scores:

        if index == song_index:
            continue

        song = df.iloc[index]["song"]
        artist = df.iloc[index]["artist"]
        genre = df.iloc[index]["genre"]

        st.write(
            f"🎵 **{song}** - {artist}  \n"
            f"Genre: {genre} | "
            f"Similarity: {score:.2f}"
        )

        count += 1

        if count == number_of_recommendations:
            break
# Out:
# Writing app.py

# %%
# %%writefile requirements.txt
#
# streamlit
# pandas
# numpy
# scikit-learn
# Out:
# Overwriting requirements.txt
